# %% [markdown]
# # AI Usage Protocol Notebook
#
# Use this notebook to document relevant AI/LLM interactions for one milestone.
#
# ## Motivation and Relevance
#
# This protocol is intended to support the documentation of AI usage in accordance with current university and NRW-related guidelines requiring transparency of AI-assisted work processes. Students must disclose relevant uses of AI tools, including revisions, translations, text generation, analysis support, structuring support, or other AI-assisted scientific activities.
#
# This protocol is not a raw chat dump. It documents all milestone-relevant AI interactions that substantially influenced scientific reasoning, understanding, decision-making, argumentation, or interpretation — including accepted, partially used, and rejected outputs.
#
# The focus is on documenting scientific reasoning and validation processes, not only final integration into the submitted work.

# %% [markdown]
# ## Protocol Metadata
#
# | Field | Value |
# |-------|-------|
# | Protocol version | `0.2` |
# | Student | Sumon Boiddo |
# | Student ID | `2220054` |
# | Email | sumon.boiddo@stud.hshl.de |
# | Institution | Hochschule Hamm-Lippstadt, Lippstadt, Germany |
# | Course | HW/SW Co-Design Seminar |
# | Milestone | **M5: Seminar Paper (Full IEEE Paper)** |
# | Topic | High-Level Synthesis with Game Theoretic Scheduling |
# | Exported at | `2026-06-19T18:00:00+02:00` |
# | Entries | 3 |

# %%
import json

with open("ai_usage_protocol_2220054_m5-seminar-paper.json", "r", encoding="utf-8") as f:
    protocol = json.load(f)

print(f"Protocol version: {protocol['protocol_version']}")
print(f"Milestone: {protocol['milestone']}")
print(f"Entries: {len(protocol['entries'])}")
print(f"Exported at: {protocol['exported_at']}")
# Out:
# Protocol version: 0.2
# Milestone: M5: Seminar Paper (Full IEEE Paper)
# Entries: 3
# Exported at: 2026-06-19T18:00:00+02:00

# %% [markdown]
# ## Documented Reasoning Episodes (3 entries)
#
# All interactions that substantially influenced the milestone work.

# %% [markdown]
# ---
# ### Interaction 1  (`e-s9t0u1v2`)
#
# **Timestamp:** 2026-06-17T10:30:00+02:00
# **AI Tool:** Claude (claude-sonnet-4-6)
#
# **Objective:**
# M5 required converting my M1-M4 bullet structures into flowing academic prose for the Introduction and Background sections. I had all the technical content but needed the transition sentences to connect the power motivation, prior methods, and the game-theoretic proposal into a coherent narrative.
#
# **Prompt:**
# ```
# I have these three ideas for the introduction: (1) power is important in VLSI because of battery life and heating; (2) HLS has three steps: scheduling, allocation, binding, and poor scheduling wastes power; (3) existing ILP and LP methods are complex and do not handle scheduling and binding together. Connect these into an introduction paragraph that leads to the game theory proposal.
# ```
#
# **AI Output Summary:**
# Claude wrote a paragraph that opened with the power motivation (battery life, reliability, 50%/10C rule), moved to HLS and its three steps, then identified the gap in existing methods (separate treatment of scheduling and binding), and ended with a sentence introducing the game-theoretic approach. The structure followed my three points exactly.
#
# **Verification:**
# - Level: `primary-source-check`
# - Checked every factual claim in the generated paragraph: 50%/10C rule confirmed in Small [3]; HLS three steps confirmed in Gajski [5] and Benini [4]; ILP/LP limitation confirmed in Shiue and Chakrabarti [2]. The game-theoretic proposal is from Murugavel and Ranganathan [1]. All content matches the references.
#
# **Evaluation:**
# - Status: `accepted`
# - Usefulness: `high`
# - None.
#
# **Integration:**
# - Used in submitted work: `True`
# - Section: Section I (Introduction)
# - Usage type: `wording-support`
# - Direct text reused: `False`
#
# **Reflection:**
# All three ideas and all the supporting facts were mine from M1. The AI helped connect them into a paragraph with smooth transitions. I rewrote the final version in my own words after using the AI output as a structural guide.

# %%
# Entry 1: e-s9t0u1v2
entry = protocol["entries"][0]
print(f"Objective: {entry['objective'][:80]}...")
print(f"Status: {entry['evaluation']['status']}")
print(f"Usefulness: {entry['evaluation']['usefulness']}")
print(f"Used in work: {entry['integration']['used_in_work']}")
# Out:
# Objective: M5 required converting my M1-M4 bullet structures into flowing academic prose fo...
# Status: accepted
# Usefulness: high
# Used in work: True

# %% [markdown]
# ---
# ### Interaction 2  (`e-t0u1v2w3`)
#
# **Timestamp:** 2026-06-18T09:30:00+02:00
# **AI Tool:** Claude (claude-sonnet-4-6)
# **Parent:** e-s9t0u1v2
#
# **Objective:**
# The methodology section (Section III) needed to present the game model, auction type selection, and three power-reduction techniques as separate subsections. I had the content from M1 but was unsure how to divide it into IEEE subsection headings that flow logically.
#
# **Prompt:**
# ```
# My methodology covers: (A) the key idea that FUs are players bidding power cost, Nash decides; (B) why I chose first-price sealed-bid over English, Dutch, and second-price; (C) three power-reduction techniques: FU sharing, path balancing, register assignment; (D) the cost function equations. Suggest four subsection headings in IEEE style that present these in logical order.
# ```
#
# **AI Output Summary:**
# Claude suggested: 'A. Modeling the Problem as a Game', 'B. Auction Type Selection', 'C. Power-Reduction Techniques', 'D. Cost Function and Optimal Assignment'. The order matched my content grouping. It added no new content suggestions.
#
# **Verification:**
# - Level: `secondary-source-check`
# - Compared the proposed headings against the structure of Murugavel and Ranganathan (2003). The paper's sections III-V cover the same topics in a similar order (game model, cost function, techniques). The subsection heading style follows IEEE conference paper conventions.
#
# **Evaluation:**
# - Status: `accepted`
# - Usefulness: `medium`
# - None.
#
# **Integration:**
# - Used in submitted work: `True`
# - Section: Section III (Methodology) — subsection headings A through D
# - Usage type: `structuring-support`
# - Direct text reused: `False`
#
# **Reflection:**
# The four subsection headings proposed by the AI matched what I already had in mind. I accepted all four headings and wrote the content of each subsection myself, drawing entirely from my M1-M3 work.

# %%
# Entry 2: e-t0u1v2w3
entry = protocol["entries"][1]
print(f"Objective: {entry['objective'][:80]}...")
print(f"Status: {entry['evaluation']['status']}")
print(f"Usefulness: {entry['evaluation']['usefulness']}")
print(f"Used in work: {entry['integration']['used_in_work']}")
# Out:
# Objective: The methodology section (Section III) needed to present the game model, auction ...
# Status: accepted
# Usefulness: medium
# Used in work: True

# %% [markdown]
# ---
# ### Interaction 3  (`e-u1v2w3x4`)
#
# **Timestamp:** 2026-06-18T15:00:00+02:00
# **AI Tool:** Claude (claude-sonnet-4-6)
# **Parent:** e-t0u1v2w3
#
# **Objective:**
# I wrote my abstract with all the required content (power motivation, DFG and auction approach, Nash equilibrium, three techniques, benchmark numbers, tradeoffs, future work). It was 180 words and I needed to confirm it covered all required abstract elements for an IEEE paper and was below the typical 200-word limit.
#
# **Prompt:**
# ```
# Here is my abstract draft: [abstract text]. Does this cover all standard IEEE abstract elements: motivation, approach, method, results, and conclusion? Is it under 200 words?
# ```
#
# **AI Output Summary:**
# Claude confirmed the abstract covered all five IEEE elements and was 178 words. It noted that the index terms listed after the abstract were good but suggested adding 'behavioral synthesis' as a keyword since it appears in the paper title of the main reference. I accepted this suggestion.
#
# **Verification:**
# - Level: `secondary-source-check`
# - Counted the abstract words independently: 178 words confirmed. Verified that 'behavioral synthesis' appears in the title of Murugavel and Ranganathan (2003) and is relevant to my index terms. The term was added to the Index Terms list.
#
# **Evaluation:**
# - Status: `partially-accepted`
# - Usefulness: `high`
# - Issue: The AI suggested adding 'behavioral synthesis' to index terms, which I accepted. Everything else in the abstract was my own text and was confirmed without change.
#
# **Integration:**
# - Used in submitted work: `True`
# - Section: Abstract and Index Terms
# - Usage type: `verification-support`
# - Direct text reused: `False`
#
# **Reflection:**
# The abstract was written entirely by me. The AI performed a structural check and confirmed the word count. I accepted the index term suggestion because it was substantively correct and directly linked to my primary reference. The abstract text itself is unchanged from my draft.

# %%
# Entry 3: e-u1v2w3x4
entry = protocol["entries"][2]
print(f"Objective: {entry['objective'][:80]}...")
print(f"Status: {entry['evaluation']['status']}")
print(f"Usefulness: {entry['evaluation']['usefulness']}")
print(f"Used in work: {entry['integration']['used_in_work']}")
# Out:
# Objective: I wrote my abstract with all the required content (power motivation, DFG and auc...
# Status: partially-accepted
# Usefulness: high
# Used in work: True

# %% [markdown]
# ## Summary Statistics

# %%
stats = protocol["summary"]
for k, v in stats.items():
    print(f"  {k}: {v}")
# Out:
#   total_entries: 3
#   accepted: 2
#   partially_accepted: 1
#   revised: 0
#   rejected: 0
#   used_in_submitted_work: 3
#   high_usefulness: 3

# %% [markdown]
# ## Academic Integrity Note
#
# The interactions documented here were used as support for understanding, structuring, wording, verification, or communication. The submitted milestone artifact does not reuse AI text directly. All technical ideas, arguments, and conclusions originate from the student's own analysis of the assigned reference (Murugavel and Ranganathan, 2003) and course materials. Scientific claims were checked against the primary source before being included in the submitted work.
#
# **Student:** Sumon Boiddo
# **Student ID:** 2220054
# **Email:** sumon.boiddo@stud.hshl.de
