# %% [markdown]
# # AI Usage Protocol Notebook
#
# Use this notebook to document relevant AI/LLM interactions for one milestone.
#
# ## Motivation and Relevance
#
# This protocol is intended to support the documentation of AI usage in accordance with current university and NRW-related guidelines requiring transparency of AI-assisted work processes. Students must disclose relevant uses of AI tools, including revisions, translations, text generation, analysis support, structuring support, or other AI-assisted scientific activities.
#
# This protocol is not a raw chat dump. It documents all milestone-relevant AI interactions that substantially influenced scientific reasoning, understanding, decision-making, argumentation, or interpretation — including accepted, partially used, and rejected outputs.
#
# The focus is on documenting scientific reasoning and validation processes, not only final integration into the submitted work.

# %% [markdown]
# ## Protocol Metadata
#
# | Field | Value |
# |-------|-------|
# | Protocol version | `0.2` |
# | Student | Sumon Boiddo |
# | Student ID | `2220054` |
# | Email | sumon.boiddo@stud.hshl.de |
# | Institution | Hochschule Hamm-Lippstadt, Lippstadt, Germany |
# | Course | HW/SW Co-Design Seminar |
# | Milestone | **M3: Critical Evaluation and Transfer** |
# | Topic | High-Level Synthesis with Game Theoretic Scheduling |
# | Exported at | `2026-06-15T18:00:00+02:00` |
# | Entries | 3 |

# %%
import json

with open("ai_usage_protocol_2220054_m3-evaluation.json", "r", encoding="utf-8") as f:
    protocol = json.load(f)

print(f"Protocol version: {protocol['protocol_version']}")
print(f"Milestone: {protocol['milestone']}")
print(f"Entries: {len(protocol['entries'])}")
print(f"Exported at: {protocol['exported_at']}")
# Out:
# Protocol version: 0.2
# Milestone: M3: Critical Evaluation and Transfer
# Entries: 3
# Exported at: 2026-06-15T18:00:00+02:00

# %% [markdown]
# ## Documented Reasoning Episodes (3 entries)
#
# All interactions that substantially influenced the milestone work.

# %% [markdown]
# ---
# ### Interaction 1  (`e-m3n4o5p6`)
#
# **Timestamp:** 2026-06-12T09:30:00+02:00
# **AI Tool:** Claude (claude-sonnet-4-6)
#
# **Objective:**
# From my M1 and M2 work I had already identified five concrete strengths of the game-theoretic HLS approach. I had them as bullet-point notes. I needed help expressing each strength clearly in academic English before writing Section I.
#
# **Prompt:**
# ```
# I have identified these five strengths of the game-theoretic HLS approach from my reading: (1) joint scheduling and binding in one auction; (2) each unit bids actual power cost, so the objective is direct; (3) no extra hardware area added; (4) runtime is comparable to ILP because player count is small; (5) power-reduction techniques (FU sharing, path balancing, register assignment) are built into the cost function. Can you help me phrase each point clearly in academic English without adding new ideas?
# ```
#
# **AI Output Summary:**
# Claude rephrased each of my five points into more formal academic sentences. It added 'Evidence:' sub-bullets suggesting I include the benchmark percentages (6.3%, 13.9%, 11.8%) under each claim. It did not introduce any new strength or change any of my assessments.
#
# **Verification:**
# - Level: `primary-source-check`
# - Verified all five strength claims against Murugavel and Ranganathan (2003) before writing the final text: joint scheduling and binding confirmed in Section IV; direct power objective confirmed in Section II; no area overhead confirmed in Section VI and benchmark table captions; runtime confirmed in Section VI; power-reduction techniques confirmed in Section V.
# - The benchmark percentages in the 'Evidence' sub-bullets were values I had already extracted from Tables I-III of the paper.
# - The final Section I text was rewritten by me in my own words after reading the AI phrasing.
#
# **Evaluation:**
# - Status: `accepted`
# - Usefulness: `medium`
# - None.
#
# **Integration:**
# - Used in submitted work: `True`
# - Section: Section I (Concrete Strengths)
# - Usage type: `wording-support`
# - Direct text reused: `False`
#
# **Reflection:**
# All five strengths were identified by me from my reading and earlier milestone work. The AI only improved the English phrasing. I verified every claim against the paper and rewrote the final text in my own words before including it in the submission.

# %%
# Entry 1: e-m3n4o5p6
entry = protocol["entries"][0]
print(f"Objective: {entry['objective'][:80]}...")
print(f"Status: {entry['evaluation']['status']}")
print(f"Usefulness: {entry['evaluation']['usefulness']}")
print(f"Used in work: {entry['integration']['used_in_work']}")
# Out:
# Objective: From my M1 and M2 work I had already identified five concrete strengths of the g...
# Status: accepted
# Usefulness: medium
# Used in work: True

# %% [markdown]
# ---
# ### Interaction 2  (`e-n4o5p6q7`)
#
# **Timestamp:** 2026-06-13T11:00:00+02:00
# **AI Tool:** Claude (claude-sonnet-4-6)
# **Parent:** e-m3n4o5p6
#
# **Objective:**
# I had extracted the benchmark power values for all seven circuits from Tables I, II, and III of Murugavel and Ranganathan (2003) by reading the paper myself. Before reproducing them in my M3 tables I wanted to verify that my percentage calculations were correct.
#
# **Prompt:**
# ```
# I have extracted these scheduling results from the paper: ILP values 24.8, 82.8, 15.6, 91.3, 262.8, 258.2, 389.7 mW and GT values 23.9, 78.7, 14.8, 82.9, 251.0, 232.8, 363.4 mW for Diff.eqn, FIR, IIR, Lattice, EWF, WAVE, NC filter. Do these give an average improvement of 6.3%?
# ```
#
# **AI Output Summary:**
# Claude calculated the seven individual improvements as 3.6%, 4.9%, 5.1%, 9.2%, 4.5%, 9.8%, 6.7%, giving an average of approximately 6.26%, which rounds to 6.3%. This confirmed that my reading of Table I was numerically correct. Claude performed only arithmetic on the values I provided and did not supply any data values itself.
#
# **Verification:**
# - Level: `primary-source-check`
# - All fourteen ILP and GT power values (seven per method) were read directly by me from Table I of Murugavel and Ranganathan (2003). AI did not provide any of these numbers.
# - I independently verified three individual improvements by hand: Diff.eqn (3.6%), Lattice (9.2%), and WAVE (9.8%). These matched the AI arithmetic.
# - The same manual verification process was applied to selected circuits from Tables II and III before reproducing those tables in the submission.
#
# **Evaluation:**
# - Status: `accepted`
# - Usefulness: `high`
# - None.
#
# **Integration:**
# - Used in submitted work: `True`
# - Section: Section IV.A (Results for Scheduling, Table I) and Section IV.D (Result Summary, Table IV)
# - Usage type: `verification-support`
# - Direct text reused: `False`
#
# **Reflection:**
# The data values came entirely from my own reading of the primary source. I used the AI only as an arithmetic checker to confirm that my percentage calculations were correct. The benchmark tables in the submission reproduce the values as cited from Murugavel and Ranganathan.

# %%
# Entry 2: e-n4o5p6q7
entry = protocol["entries"][1]
print(f"Objective: {entry['objective'][:80]}...")
print(f"Status: {entry['evaluation']['status']}")
print(f"Usefulness: {entry['evaluation']['usefulness']}")
print(f"Used in work: {entry['integration']['used_in_work']}")
# Out:
# Objective: I had extracted the benchmark power values for all seven circuits from Tables I,...
# Status: accepted
# Usefulness: high
# Used in work: True

# %% [markdown]
# ---
# ### Interaction 3  (`e-o5p6q7r8`)
#
# **Timestamp:** 2026-06-14T09:00:00+02:00
# **AI Tool:** Claude (claude-sonnet-4-6)
# **Parent:** e-n4o5p6q7
#
# **Objective:**
# I had already identified three future-work directions from my critical evaluation: (1) joint power and latency optimisation; (2) adding interconnect binding to the cost function; (3) faster Nash equilibrium computation for larger circuits. I asked the AI whether there was a relevant fourth direction connected to machine learning or AI-assisted scheduling, to make the future-work section more complete.
#
# **Prompt:**
# ```
# I already have three future-work directions: joint power-latency optimisation, interconnect binding, and faster Nash equilibrium computation. Is there a fourth direction in HLS power optimisation that uses machine learning or AI? Give me the direction only, not a full explanation.
# ```
#
# **AI Output Summary:**
# Claude suggested: 'Machine-learning-guided bidding: train a model on past designs so that functional units make smarter initial bids, reducing the search space for the Nash equilibrium.' This matched the general direction I was considering. Claude did not claim this idea was absent from all existing literature.
#
# **Verification:**
# - Level: `secondary-source-check`
# - Checked whether ML-guided bidding for HLS scheduling is discussed in Murugavel and Ranganathan (2003). It is not mentioned in the 2003 paper.
# - I did not perform a full literature review on ML-guided HLS bidding. The idea is included in the submission only as a possible future direction, not as a verified research gap.
# - The final future-work paragraph is written in my own words and clearly separates this possible direction from the verified contributions of the original paper.
#
# **Evaluation:**
# - Status: `partially-accepted`
# - Usefulness: `high`
# - Issue: The ML-guided bidding idea was accepted only as a plausible extension, not as a proven or verified result.
# - Issue: This direction is not discussed in the 2003 paper, but I did not verify whether it exists elsewhere in the literature. It is presented only as a possible future direction.
# - Issue: I did not use the AI's wording. The idea was restated carefully in my own words and framed as exploratory.
#
# **Integration:**
# - Used in submitted work: `True`
# - Section: Section VI (Extensions and Open Questions, point 4)
# - Usage type: `concept-extension`
# - Direct text reused: `False`
#
# **Reflection:**
# The ML-guided bidding idea was treated only as a possible future direction. It was not presented as a result of the original paper. I accepted the idea partially because it fits the direction of HLS optimisation, but I rewrote it carefully and clearly separated it from the verified contributions of the paper. The first three future-work directions in Section VI were my own and are directly grounded in the paper's identified limitations.

# %%
# Entry 3: e-o5p6q7r8
entry = protocol["entries"][2]
print(f"Objective: {entry['objective'][:80]}...")
print(f"Status: {entry['evaluation']['status']}")
print(f"Usefulness: {entry['evaluation']['usefulness']}")
print(f"Used in work: {entry['integration']['used_in_work']}")
# Out:
# Objective: I had already identified three future-work directions from my critical evaluatio...
# Status: partially-accepted
# Usefulness: high
# Used in work: True

# %% [markdown]
# ## Summary Statistics

# %%
stats = protocol["summary"]
for k, v in stats.items():
    print(f"  {k}: {v}")
# Out:
#   total_entries: 3
#   accepted: 2
#   partially_accepted: 1
#   revised: 0
#   rejected: 0
#   used_in_submitted_work: 3
#   high_usefulness: 3

# %% [markdown]
# ## Academic Integrity Note
#
# The interactions documented here were used as support for understanding, structuring, wording, verification, or communication. The submitted milestone artifact does not reuse AI text directly. All technical ideas, arguments, and conclusions originate from the student's own analysis of the assigned reference (Murugavel and Ranganathan, 2003) and course materials. Scientific claims were checked against the primary source before being included in the submitted work.
#
# **Student:** Sumon Boiddo
# **Student ID:** 2220054
# **Email:** sumon.boiddo@stud.hshl.de
