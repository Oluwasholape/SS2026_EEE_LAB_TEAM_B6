# %% [markdown]
# # AI Usage Protocol Notebook
#
# Use this notebook to document relevant AI/LLM interactions for one milestone.
#
# ## Motivation and Relevance
#
# This protocol is intended to support the documentation of AI usage in accordance with current university and NRW-related guidelines requiring transparency of AI-assisted work processes. Students must disclose relevant uses of AI tools, including revisions, translations, text generation, analysis support, structuring support, or other AI-assisted scientific activities.
#
# This protocol is not a raw chat dump. It documents all milestone-relevant AI interactions that substantially influenced scientific reasoning, understanding, decision-making, argumentation, or interpretation — including accepted, partially used, and rejected outputs.
#
# The focus is on documenting scientific reasoning and validation processes, not only final integration into the submitted work.

# %% [markdown]
# ## Protocol Metadata
#
# | Field | Value |
# |-------|-------|
# | Protocol version | `0.2` |
# | Student | Sumon Boiddo |
# | Student ID | `2220054` |
# | Email | sumon.boiddo@stud.hshl.de |
# | Institution | Hochschule Hamm-Lippstadt, Lippstadt, Germany |
# | Course | HW/SW Co-Design Seminar |
# | Milestone | **M4: Advantages, Applications, Future Work, Conclusion** |
# | Topic | High-Level Synthesis with Game Theoretic Scheduling |
# | Exported at | `2026-06-17T18:00:00+02:00` |
# | Entries | 3 |

# %%
import json

with open("ai_usage_protocol_2220054_m4-advantages-applications.json", "r", encoding="utf-8") as f:
    protocol = json.load(f)

print(f"Protocol version: {protocol['protocol_version']}")
print(f"Milestone: {protocol['milestone']}")
print(f"Entries: {len(protocol['entries'])}")
print(f"Exported at: {protocol['exported_at']}")
# Out:
# Protocol version: 0.2
# Milestone: M4: Advantages, Applications, Future Work, Conclusion
# Entries: 3
# Exported at: 2026-06-17T18:00:00+02:00

# %% [markdown]
# ## Documented Reasoning Episodes (3 entries)
#
# All interactions that substantially influenced the milestone work.

# %% [markdown]
# ---
# ### Interaction 1  (`e-p6q7r8s9`)
#
# **Timestamp:** 2026-06-15T10:00:00+02:00
# **AI Tool:** Claude (claude-sonnet-4-6)
#
# **Objective:**
# M4 required prose paragraphs instead of bullet points. I had my advantages and limitations in bullet form from M3. I needed help turning them into coherent academic paragraphs while keeping all my own ideas and not adding anything new.
#
# **Prompt:**
# ```
# I have these advantages in bullet form: (1) each FU acts as a player, Nash equilibrium gives the power-minimising assignment, reduces switching activity; (2) no area overhead because no new hardware is added, only the assignment is changed. And this limitation: power is prioritised so latency may increase slightly. Convert these into two paragraphs of academic prose without adding any new ideas.
# ```
#
# **AI Output Summary:**
# Claude converted my bullet points into two paragraphs. The first paragraph described the Nash equilibrium mechanism and its effect on switching activity. The second covered the no-area-overhead advantage. The limitation was added as a final sentence in the second paragraph. No new technical claims were introduced.
#
# **Verification:**
# - Level: `primary-source-check`
# - Read the generated paragraphs against my M3 bullet list and against Murugavel and Ranganathan (2003). All claims in the paragraphs match what I had in bullets and are supported by the paper. The limitation (latency increase) is confirmed in Section VI of the paper.
#
# **Evaluation:**
# - Status: `accepted`
# - Usefulness: `high`
# - None.
#
# **Integration:**
# - Used in submitted work: `True`
# - Section: Section I (Advantages and Limitations)
# - Usage type: `wording-support`
# - Direct text reused: `False`
#
# **Reflection:**
# All technical ideas and claims are mine from M1-M3. The AI only converted my bullet structure into prose format. I edited the generated paragraphs to match my voice and confirmed every factual claim against the paper before including them.

# %%
# Entry 1: e-p6q7r8s9
entry = protocol["entries"][0]
print(f"Objective: {entry['objective'][:80]}...")
print(f"Status: {entry['evaluation']['status']}")
print(f"Usefulness: {entry['evaluation']['usefulness']}")
print(f"Used in work: {entry['integration']['used_in_work']}")
# Out:
# Objective: M4 required prose paragraphs instead of bullet points. I had my advantages and l...
# Status: accepted
# Usefulness: high
# Used in work: True

# %% [markdown]
# ---
# ### Interaction 2  (`e-q7r8s9t0`)
#
# **Timestamp:** 2026-06-16T09:00:00+02:00
# **AI Tool:** Claude (claude-sonnet-4-6)
# **Parent:** e-p6q7r8s9
#
# **Objective:**
# I wanted the applications section to connect the power-reduction result directly to IoT and mobile device use cases. I had the connection in my notes but was not sure how to express the chain of reasoning clearly in English.
#
# **Prompt:**
# ```
# I want to write this reasoning as one paragraph: IoT/wearables/mobile have small batteries and strict power limits, so less power means longer battery life and less heat. HLS with game theory and Nash equilibrium makes scheduling and binding systematic so power is reduced. In future, AI or ML could learn from past designs and make even smarter power decisions for larger circuits. Connect these ideas as a flowing paragraph.
# ```
#
# **AI Output Summary:**
# Claude connected the three ideas into a flowing paragraph. The IoT motivation and the AI future direction were joined by a bridge sentence about HLS systematising the decision process. The paragraph was slightly more formal than my note phrasing but contained no new ideas.
#
# **Verification:**
# - Level: `secondary-source-check`
# - Checked that the IoT application claim is consistent with M2 Section V (Embedded Systems Constraints and Consequences) and that the AI/ML future direction is consistent with M3 Section VI extension point 4. Both match. No new claims were introduced.
#
# **Evaluation:**
# - Status: `accepted`
# - Usefulness: `medium`
# - None.
#
# **Integration:**
# - Used in submitted work: `True`
# - Section: Section II (Applications and Relevance)
# - Usage type: `wording-support`
# - Direct text reused: `False`
#
# **Reflection:**
# The application targets (IoT, mobile, wearables) and the ML future direction were already in my milestone notes. The AI made the paragraph flow better. I adjusted the wording before including it in the submission.

# %%
# Entry 2: e-q7r8s9t0
entry = protocol["entries"][1]
print(f"Objective: {entry['objective'][:80]}...")
print(f"Status: {entry['evaluation']['status']}")
print(f"Usefulness: {entry['evaluation']['usefulness']}")
print(f"Used in work: {entry['integration']['used_in_work']}")
# Out:
# Objective: I wanted the applications section to connect the power-reduction result directly...
# Status: accepted
# Usefulness: medium
# Used in work: True

# %% [markdown]
# ---
# ### Interaction 3  (`e-r8s9t0u1`)
#
# **Timestamp:** 2026-06-16T14:00:00+02:00
# **AI Tool:** Claude (claude-sonnet-4-6)
# **Parent:** e-q7r8s9t0
#
# **Objective:**
# I wrote a first draft of the conclusion but it was too short and did not mention all three remaining challenges (latency, interconnect, scalability). I wanted help expanding it while keeping only my own ideas.
#
# **Prompt:**
# ```
# My conclusion draft: 'This work showed that HLS scheduling and binding can be solved with Nash equilibrium and power is reduced. Future work needs to fix latency, interconnect, and speed for large circuits.' Can you expand this to a short academic conclusion paragraph that mentions all three future challenges clearly?
# ```
#
# **AI Output Summary:**
# Claude expanded the paragraph to mention: (1) the main result (scheduling and binding solved via Nash equilibrium, power reduced without area increase), (2) latency as a remaining challenge requiring co-optimisation, (3) interconnect binding as a missing model component, (4) Nash equilibrium scalability for large circuits as a computational challenge. The conclusion was three sentences long.
#
# **Verification:**
# - Level: `primary-source-check`
# - Verified each of the four points in the expanded conclusion against the paper: main result matches Tables I-III, latency issue matches Section VI Assumption 1, interconnect gap matches Section VI Assumption 4, scalability issue matches Section V complexity analysis. All confirmed.
#
# **Evaluation:**
# - Status: `partially-accepted`
# - Usefulness: `high`
# - Issue: The AI wrote 'power reduced without area increase' as a single clause which I preferred to separate into two distinct points for clarity. I restructured the sentence before using it in the submission.
#
# **Integration:**
# - Used in submitted work: `True`
# - Section: Section IV (Conclusion)
# - Usage type: `wording-support`
# - Direct text reused: `False`
#
# **Reflection:**
# The three future work challenges were my own list from M3. The AI helped expand my short draft into a proper conclusion. I rewrote one sentence to separate the area and power result more clearly. The final conclusion is my own text, not a copy of the AI output.

# %%
# Entry 3: e-r8s9t0u1
entry = protocol["entries"][2]
print(f"Objective: {entry['objective'][:80]}...")
print(f"Status: {entry['evaluation']['status']}")
print(f"Usefulness: {entry['evaluation']['usefulness']}")
print(f"Used in work: {entry['integration']['used_in_work']}")
# Out:
# Objective: I wrote a first draft of the conclusion but it was too short and did not mention...
# Status: partially-accepted
# Usefulness: high
# Used in work: True

# %% [markdown]
# ## Summary Statistics

# %%
stats = protocol["summary"]
for k, v in stats.items():
    print(f"  {k}: {v}")
# Out:
#   total_entries: 3
#   accepted: 2
#   partially_accepted: 1
#   revised: 0
#   rejected: 0
#   used_in_submitted_work: 3
#   high_usefulness: 3

# %% [markdown]
# ## Academic Integrity Note
#
# The interactions documented here were used as support for understanding, structuring, wording, verification, or communication. The submitted milestone artifact does not reuse AI text directly. All technical ideas, arguments, and conclusions originate from the student's own analysis of the assigned reference (Murugavel and Ranganathan, 2003) and course materials. Scientific claims were checked against the primary source before being included in the submitted work.
#
# **Student:** Sumon Boiddo
# **Student ID:** 2220054
# **Email:** sumon.boiddo@stud.hshl.de
